# %%
import pandas as pd
import matplotlib.pyplot as plt

df= pd.read_excel("Pumpkin_Seeds_Dataset.xlsx")
df.head();
df.plot.box(title='Boxplot with pandas');
print("Something new !!! ")
df.shape

#df.dtypes
#ax = plt.boxplot(data, widths=(0.25, 0.5))
# Out:
# Something new !!!
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %%
print(" This is creating the Histogram!!")
hist = df.hist(bins=13)
# Out:
#  This is creating the Histogram!!

# %%
corr = df.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_07c19_row0_col0, #T_07c19_row0_col4, #T_07c19_row0_col5, #T_07c19_row1_col1, #T_07c19_row2_col2, #T_07c19_row3_col3, #T_07c19_row4_col0, #T_07c19_row4_col4, #T_07c19_row4_col5, #T_07c19_row5_col0, #T_07c19_row5_col4, #T_07c19_row5_col5, #T_07c19_row6_col6, #T_07c19_row7_col7, #T_07c19_row8_col8, #T_07c19_row9_col9, #T_07c19_row10_col10, #T_07c19_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_07c19_row0_col1, #T_07c19_row5_col1 {
#   background-color: #c53334;
#   color: #f1f1f1;
# }
# #T_07c19_row0_col2, #T_07c19_row4_col2, #T_07c19_row5_col2 {
#   background-color: #dd5f4b;
#   color: #f1f1f1;
# }
# #T_07c19_row0_col3, #T_07c19_row3_col11, #T_07c19_row4_col3 {
#   background-color: #ed8366;
#   color: #f1f1f1;
# }
# #T_07c19_row0_col6, #T_07c19_row0_col10, #T_07c19_row4_col6, #T_07c19_row4_col10, #T_07c19_row5_col6, #T_07c19_row5_col10 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_07c19_row0_col7 {
# ...

# %%
correlation = df["Equiv_Diameter"].corr(df["Convex_Area"])

correlation
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %%
import numpy as np

matrix = df.corr().abs()
matrix.head()
upper = matrix.where(np.triu(np.ones(matrix.shape),k=1).astype(np.bool))
upper
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   """
#                    Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  \
# Area                NaN   0.928548           0.789133           0.685304
# Perimeter           NaN        NaN           0.946181           0.392913
# Major_Axis_Length   NaN        NaN                NaN           0.099376
# Minor_Axis_Length   NaN        NaN                NaN                NaN
# Convex_Area         NaN        NaN                NaN                NaN
# Equiv_Diameter      NaN        NaN                NaN                NaN
# ...

# %%
print(df.isna().sum());
# Out:
# Area                 0
# Perimeter            0
# Major_Axis_Length    0
# Minor_Axis_Length    0
# Convex_Area          0
# Equiv_Diameter       0
# Eccentricity         0
# Solidity             0
# Extent               0
# Roundness            0
# Aspect_Ration        0
# Compactness          0
# Class                0
# dtype: int64

# %%
to_drop = [column for column in upper.columns if any(upper[column] > 0.95)]
print(); print(to_drop)
# Out:
# ['Convex_Area', 'Equiv_Diameter', 'Aspect_Ration', 'Compactness']

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-75eb11363902> in <cell line: 7>()
#       5
#       6 reg = LinearRegression()
# ----> 7 reg.fit(X_train, y_train)
#       8
#       9 # Predict on test set
#
# NameError: name 'X_train' is not defined
